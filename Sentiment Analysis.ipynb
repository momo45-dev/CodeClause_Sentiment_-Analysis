# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
from textblob import TextBlob
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import mean_squared_error
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_predict
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
import scipy

# %%
df=pd.read_csv(r'D:\Desktop\C++\New folder\Datafiniti_Hotel_Reviews_Jun19.csv')
df
# Out:
#                                            reviews.text
# 0     This hotel was nice and quiet. Did not know, t...
# 1     We stayed in the king suite with the separatio...
# 2     Parking was horrible, somebody ran into my ren...
# 3     Not cheap but excellent location. Price is som...
# 4     If you get the room that they advertised on th...
# ...                                                 ...
# 9995  My friends and I took a trip to Hampton for th...
# 9996  from check in to departure, staff is friendly,...
# 9997  This Hampton is located on a quiet street acro...
# 9998  Awesome wings (my favorite was garlic parmesan...
# 9999  Clean facility just off freeway ..... staff fr...
#
# [10000 rows x 1 columns]

# %%
df.describe()
# Out:
#        reviews.text
# count         10000
# unique         9770
# top        MoreMore
# freq             18

# %%
 

def sentiment(label):
    if label <0:
        return "Negative"
    elif label <=0.2:
        return "Neutral"
    elif label>0.2:
        return "Positive"

# %%
def polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['polarity'] = df['reviews.text'].apply(polarity)
df.head(10)
# Out:
#                                         reviews.text  polarity
# 0  This hotel was nice and quiet. Did not know, t...  0.187500
# 1  We stayed in the king suite with the separatio...  0.399524
# 2  Parking was horrible, somebody ran into my ren... -0.350000
# 3  Not cheap but excellent location. Price is som...  0.495238
# 4  If you get the room that they advertised on th...  0.214286
# 5  This is such a fun, lovely hotel. The attentio...  0.198077
# 6  We recently stayed at this hotel on a trip to ...  0.182143
# 7  I reserved a room a week in advance, knowing a... -0.400000
# 8                                           MoreMore  0.000000
# 9  Hello, I have traveled a lot and abroad and by... -0.342857

# %%
df['sentiment'] = df['polarity'].apply(sentiment)
df
# Out:
#                                            reviews.text  polarity sentiment
# 0     This hotel was nice and quiet. Did not know, t...  0.187500   Neutral
# 1     We stayed in the king suite with the separatio...  0.399524  Positive
# 2     Parking was horrible, somebody ran into my ren... -0.350000  Negative
# 3     Not cheap but excellent location. Price is som...  0.495238  Positive
# 4     If you get the room that they advertised on th...  0.214286  Positive
# ...                                                 ...       ...       ...
# 9995  My friends and I took a trip to Hampton for th...  0.475000  Positive
# 9996  from check in to departure, staff is friendly,...  0.298519  Positive
# 9997  This Hampton is located on a quiet street acro...  0.071429   Neutral
# 9998  Awesome wings (my favorite was garlic parmesan...  0.875000  Positive
# 9999  Clean facility just off freeway ..... staff fr...  0.300333  Positive
#
# [10000 rows x 3 columns]

# %%
y=df.iloc[:,2]
X=df.iloc[:,0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_test[0]
# Out:
# 'This hotel was nice and quiet. Did not know, there was train track near by. But it was only few train passed during our stay. Best Western changed hotel classification. The Plus category are not the same as before.'

# %%
## Bags_of_words

# %%
vect=CountVectorizer()
vect_x_train = vect.fit_transform(X_train)
vect_x_test = vect.transform(X_test)
X_test=vect.transform(X_test)

# %%
vect_x_train.shape
# Out:
# (8000, 19938)

# %% [markdown]
# # Classification

# %% [markdown]
# # Linear SVC

# %%
SVCmodel = LinearSVC()
SVCmodel.fit(vect_x_train, y_train)
LinearSVC()
# Out:
# C:\Users\oem\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
svc_pred = SVCmodel.predict(vect_x_test)
print(classification_report(y_test, svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.51      0.42      0.46        98
#      Neutral       0.66      0.60      0.63       468
#     Positive       0.89      0.93      0.91      1434
#
#     accuracy                           0.83      2000
#    macro avg       0.69      0.65      0.67      2000
# weighted avg       0.82      0.83      0.82      2000

# %%
model = KNeighborsClassifier(n_neighbors=3)

# Train the model using the training sets
model.fit(vect_x_train,y_train)

#Predict Output
predicted= model.predict(vect_x_test) # 0:Overcast, 2:Mild

print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.19      0.14      0.16        98
#      Neutral       0.45      0.24      0.31       468
#     Positive       0.77      0.90      0.83      1434
#
#     accuracy                           0.71      2000
#    macro avg       0.47      0.43      0.43      2000
# weighted avg       0.67      0.71      0.68      2000

# %%
from sklearn.tree import DecisionTreeClassifier
clf_dec = DecisionTreeClassifier()
clf_dec.fit(vect_x_train,y_train)

cld_pred=clf_dec.predict(vect_x_test)

print(classification_report(y_test, cld_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.32      0.29      0.30        98
#      Neutral       0.45      0.43      0.44       468
#     Positive       0.84      0.85      0.84      1434
#
#     accuracy                           0.73      2000
#    macro avg       0.53      0.52      0.53      2000
# weighted avg       0.72      0.73      0.72      2000

# %%
logreg = LogisticRegression(multi_class='multinomial', solver='lbfgs')
logreg.fit(vect_x_train, y_train)
logreg_pred = logreg.predict(vect_x_test)
print(classification_report(y_test, logreg_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.60      0.42      0.49        98
#      Neutral       0.69      0.65      0.67       468
#     Positive       0.90      0.94      0.92      1434
#
#     accuracy                           0.85      2000
#    macro avg       0.73      0.67      0.69      2000
# weighted avg       0.84      0.85      0.84      2000
# C:\Users\oem\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
parameters = {
    'penalty' : ['l1','l2'], 
    'C'       : np.logspace(-3,3,7),
   
}

# %%
clf_grid = GridSearchCV(logreg,                    
                   param_grid = parameters,   
                   scoring='accuracy',        
                   cv=10)

# %%
clf_grid.fit(vect_x_train, y_train)
# Out:
# C:\Users\oem\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\oem\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print("Best parameter:", clf_grid.best_params_)
# Out:
# Best parameter: {'C': 1.0, 'penalty': 'l2'}

# %%
logreg2 = LogisticRegression(C=1,penalty="l2")
logreg2.fit(vect_x_train, y_train)
logreg_pred = logreg2.predict(vect_x_test)
print(classification_report(y_test, logreg_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.60      0.42      0.49        98
#      Neutral       0.69      0.65      0.67       468
#     Positive       0.90      0.94      0.92      1434
#
#     accuracy                           0.85      2000
#    macro avg       0.73      0.67      0.69      2000
# weighted avg       0.84      0.85      0.84      2000
# C:\Users\oem\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
